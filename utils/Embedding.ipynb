# %%
import os
from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# ## Embedding model from langchain
#
# #### Paid
# - OpenAI
# - Azure
# - GoogleCloud
# - AWS
# #### free tire
# - Voyage AI
# - Cohere
# #### Free
# Free if self-hosted
# - Hugging Face
# - Ollama
# - Mistral AI
# - NVIDIA

# %%
from langchain_ollama import OllamaEmbeddings

# %%
embeddings_model = OllamaEmbeddings(model='llama3.2:1b')

# %% [markdown]
# ### Documents Embeddings
# Returns a list of lists of floats

# %%
embeddings = embeddings_model.embed_documents(
    [
        "Hi there!",
        "Oh, hello!",
        "What's your name?",
        "My friends call me World",
        "Hello World!"
    ]
)

# %%
len(embeddings)
# Out:
# 5

# %%
len(embeddings[0])
# Out:
# 2048

# %% [markdown]
# ## Query Embeddings
# Returns a list of floats

# %%
embedded_query = embeddings_model.embed_query("What was the name mentioned in the conversation?")
embedded_query[:5]
# Out:
# [-0.01655699, 0.043639902, 0.007745032, -0.002040398, 0.047778036]
