# %%
# !pip install --upgrade --quiet langchain-google-community[drive]
# Out:
# [notice] A new release of pip available: 22.3 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_google_community import GoogleDriveLoader
import os

# %%
key="AIzaSyCfF5i7rSn7UXjsEp9tnJ4kAbZ0HmEAq90"

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = ""

# %%
loader = GoogleDriveLoader(
    folder_id="0B1mMfHWelig2fktwSS1lbGsza2ZYelhSLUdPdWdFWW5nQVh2Y3l3VDBWQS1sYjlzT3VUR0E",
    file_types=["document", "sheet"],
    recursive=False,
    credentials_path = "credentials.json",
    token_path = "token.json"
)

# %%
docs = loader.load()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=457625961211-0foug6i830k5ncjv569pql51hke1aq31.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A52735%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.file&state=shmQsZAjDTYEeJJpoIromZ5S52YPRD&access_type=offline
